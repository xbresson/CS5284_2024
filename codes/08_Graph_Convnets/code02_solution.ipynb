# %% [markdown]
# # Lecture : Graph Convolutional Networks
#
# ## Lab 02 : GCNs - Solution
#
# Kipf, Welling, Semi-supervised classification with graph convolutional networks, 2016
# https://arxiv.org/pdf/1609.02907.pdf
#
# ### Xavier Bresson
#
# <br>
# Notebook goals :<br>
# • Add node features to DGL graphs  <br>
# • Create a DGL batch of graphs  <br>
# • Implement GCN message-passing function with DGL  <br>

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/GML_May23_codes/codes/05_Graph_Convnets'
    print(path_to_file)
    # change current path to the folder containing "path_to_file"
    os.chdir(path_to_file)
    # !pwd
    # !pip install dgl==1.0.0 # Install DGL

# %%
# Libraries
import dgl
from dgl.data import MiniGCDataset
import matplotlib.pyplot as plt
import networkx as nx
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# %% [markdown]
# # Visualize the artifical graph dataset used in this notebook

# %%
dataset = MiniGCDataset(8, 10, 20) # DGL artificial dataset

# visualise the 8 classes of graphs
for c in range(8):
    graph, label = dataset[c] 
    #fig, ax = plt.subplots()
    fig, ax = plt.subplots(figsize=(4,4))
    nx.draw(graph.to_networkx(), ax=ax)
    ax.set_title('Class: {:d}'.format(label))
    plt.show()

# %% [markdown]
# # Generate train, val and test datasets
#
# ## Add node feature

# %%
# Add node features to graphs
def add_node_features(dataset):
    for (graph,_) in dataset:
        # node feature = node in-degree
        # graph.ndata['feat'].size()=(num_nodes,1) and graph.ndata['feat'].type()=torch.FloatTensor
        # you may use ".in_degrees(), .view(), .float()" 
        #graph.ndata['feat'] = ### YOUR CODE HERE
        graph.ndata['feat'] = graph.in_degrees().view(-1, 1).float() # node feat is in-degree
    return dataset

# Generate graph datasets
trainset = MiniGCDataset(350, 10, 20)
testset = MiniGCDataset(100, 10, 20)
valset = MiniGCDataset(100, 10, 20)
trainset = add_node_features(trainset)
testset = add_node_features(testset)
valset = add_node_features(valset)
print(trainset[0])
# Out:
# (Graph(num_nodes=15, num_edges=45,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={}), tensor(0))

# %% [markdown]
# # Define the collate function to prepare a batch of DGL graphs and test it

# %%
# collate function prepares a batch of graphs and labels 
def collate(samples):
    # Input sample is a list of pairs (graph, label)
    graphs, labels = map(list, zip(*samples)) # "graphs" is a list of "batch_size" DGL graphs
                                              # "labels" is a list of "batch_size" class labels
    # Create the DGL batch of graphs, which is equivalent to build a block diagonal matrix with all graphs in the batch
    # You may use DGL module "dgl.batch()" and print the result
    #batch_graphs = ### YOUR CODE HERE
    batch_graphs = dgl.batch(graphs)    # batch of graphs
    batch_labels = torch.tensor(labels) # batch of labels
    return batch_graphs, batch_labels

# Generate a batch of graphs
batch_size = 10
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate)
batch_graphs, batch_labels = list(train_loader)[0]
print(batch_graphs)
print(batch_labels)
batch_x = batch_graphs.ndata['feat']
print('batch_x:',batch_x.size())
# Out:
# Graph(num_nodes=140, num_edges=738,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={})
# tensor([6, 2, 1, 7, 1, 0, 0, 0, 5, 1])
# batch_x: torch.Size([140, 1])

# %% [markdown]
# # Design the class of GCN networks with DGL
#
# Node update equation:
# \begin{eqnarray}
# h_i^{\ell+1} &=& h_i^{\ell} + \text{ReLU} \left( \frac{1}{\sqrt{d_i}} \sum_{j\sim i} \frac{1}{\sqrt{d_j}} W^\ell h_j^{\ell} \right)
# \end{eqnarray}

# %%
# MLP layer for classification
class MLP_layer(nn.Module): 
    
    def __init__(self, input_dim, output_dim, L=2): # L = nb of hidden layers
        super(MLP_layer, self).__init__()
        list_FC_layers = [ nn.Linear( input_dim, input_dim, bias=True ) for l in range(L) ]
        list_FC_layers.append(nn.Linear( input_dim, output_dim , bias=True ))
        self.FC_layers = nn.ModuleList(list_FC_layers)
        self.L = L
        
    def forward(self, x):
        y = x
        for l in range(self.L):
            y = self.FC_layers[l](y)
            y = torch.relu(y)
        y = self.FC_layers[self.L](y)
        return y

        
# class of GatedGCN layer  
class GCN_layer(nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(GCN_layer, self).__init__()
        self.W = nn.Linear(input_dim, output_dim, bias=True)
        
    # Step 1 of message-passing with DGL: 
    #   Node feature and edge features are passed along edges (src/j => dst/i) 
    def message_func(self, edges):
        # Pass the messages Wh_j and d_j (in-degree_j) to the node i
        # You may use ".src[]"
        #Whj = ### YOUR CODE HERE
        #dj = ### YOUR CODE HERE
        Whj = edges.src['Wh'] 
        dj = edges.src['d'] 
        return {'Whj' : Whj, 'dj' : dj}

    # Step 2 of message-passing with DGL: 
    #   Reduce function collects all messages={Whj, dj} sent to node dst/i with Step 1
    def reduce_func(self, nodes):
        # You may use ".mailbox[]"
        #Whj = ### YOUR CODE HERE
        #dj = ### YOUR CODE HERE
        Whj = nodes.mailbox['Whj']
        dj = nodes.mailbox['dj']
        inv_sqrt_dj = torch.pow(dj, -0.5) # 1/sqrt(d_j)
        h = torch.sum( inv_sqrt_dj * Whj, dim=1 ) # hi = sum_j 1/sqrt(d_j) * Bhj 
        return {'h' : h} # return update node feature hi
    
    def forward(self, g, h):
        h_in = h # residual connection
        g.ndata['Wh'] = self.W(h) # linear transformation 
        d = g.in_degrees().view(-1, 1).float() # in-degree d_i
        g.ndata['d'] = d
        g.update_all(self.message_func,self.reduce_func) # update the node feature with DGL
        h = g.ndata['h'] # collect the node output of graph convolution
        inv_sqrt_d = torch.pow(d, -0.5) # 1/ sqrt(d_i)
        h = inv_sqrt_d * h # h_i / sqrt(d_i)
        h = torch.relu(h) # non-linear activation
        h = h_in + h # residual connection
        return h
    
    
class GCN_net(nn.Module):
    
    def __init__(self, net_parameters):
        super(GCN_net, self).__init__()
        input_dim = net_parameters['input_dim']
        hidden_dim = net_parameters['hidden_dim']
        output_dim = net_parameters['output_dim']
        L = net_parameters['L']
        self.embedding_h = nn.Linear(input_dim, hidden_dim)
        self.GCN_layers = nn.ModuleList([ GCN_layer(hidden_dim, hidden_dim) for _ in range(L) ]) 
        self.MLP_layer = MLP_layer(hidden_dim, output_dim)
        
    def forward(self, g, h):
        
        # input embedding
        h = self.embedding_h(h)
        
        # graph convnet layers
        for GCNlayer in self.GCN_layers:
            h = GCNlayer(g,h)
        
        # MLP classifier
        g.ndata['h'] = h
        y = dgl.mean_nodes(g,'h')
        y = self.MLP_layer(y)
        
        return y    
    
    def loss(self, y_scores, y_labels):
        loss = nn.CrossEntropyLoss()(y_scores, y_labels)
        return loss        
        
    def accuracy(self, scores, targets):
        scores = scores.detach().argmax(dim=1)
        acc = (scores==targets).float().sum().item()
        return acc
    
    def update(self, lr):       
        update = torch.optim.Adam( self.parameters(), lr=lr )
        return update


# Instantiate one network (testing)
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
print(net)

def display_num_param(net):
    nb_param = 0
    for param in net.parameters():
        nb_param += param.numel()
    print('Number of parameters: {} ({:.2f} million)'.format(nb_param, nb_param/1e6))
    return nb_param/1e6
display_num_param(net)
# Out:
# GCN_net(
#   (embedding_h): Linear(in_features=1, out_features=128, bias=True)
#   (GCN_layers): ModuleList(
#     (0-3): 4 x GCN_layer(
#       (W): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (MLP_layer): MLP_layer(
#     (FC_layers): ModuleList(
#       (0-1): 2 x Linear(in_features=128, out_features=128, bias=True)
#       (2): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
# )
# Number of parameters: 100360 (0.10 million)
# 0.10036

# %% [markdown]
# # Train the network

# %%
def run_one_epoch(net, data_loader, train=True):
    if train:
        net.train()
    else:
        net.eval()
    epoch_loss = 0
    epoch_acc = 0
    nb_data = 0
    gpu_mem = 0
    for iter, (batch_graphs, batch_labels) in enumerate(data_loader):
        batch_x = batch_graphs.ndata['feat']
        batch_labels = batch_labels
        batch_scores = net.forward(batch_graphs, batch_x)
        loss = net.loss(batch_scores, batch_labels)
        if train:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        epoch_loss += loss.detach().item()
        epoch_acc += net.accuracy(batch_scores,batch_labels)
        nb_data += batch_labels.size(0)
    epoch_loss /= (iter + 1)
    epoch_acc /= nb_data
    return epoch_loss, epoch_acc 


# dataset loaders
train_loader = DataLoader(trainset, batch_size=50, shuffle=True, collate_fn=collate)
test_loader = DataLoader(testset, batch_size=50, shuffle=False, collate_fn=collate)
val_loader = DataLoader(valset, batch_size=50, shuffle=False, drop_last=False, collate_fn=collate)

# Instantiate one network
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
display_num_param(net)

# optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

# training loop
for epoch in range(50):
    start = time.time()
    epoch_train_loss, epoch_train_acc = run_one_epoch(net, train_loader, True)
    with torch.no_grad(): 
        epoch_test_loss, epoch_test_acc = run_one_epoch(net, test_loader, False)
        epoch_val_loss, epoch_val_acc = run_one_epoch(net, val_loader, False)  
    print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss))
    print('                      train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}'.format(epoch_train_acc, epoch_test_acc, epoch_val_acc))
# Out:
# Number of parameters: 100360 (0.10 million)
# Epoch 0, time 5.9993, train_loss: 2.2630, test_loss: 2.1702, val_loss: 2.1702
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 1, time 1.2689, train_loss: 2.0680, test_loss: 2.0471, val_loss: 2.0471
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 2, time 2.8372, train_loss: 1.9900, test_loss: 1.9775, val_loss: 1.9775
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 3, time 5.2233, train_loss: 1.9412, test_loss: 1.9434, val_loss: 1.9434
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 4, time 5.1306, train_loss: 1.9195, test_loss: 1.9230, val_loss: 1.9230
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 5, time 7.4647, train_loss: 1.9020, test_loss: 1.9089, val_loss: 1.9089
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 6, time 6.5368, train_loss: 1.8866, test_loss: 1.8937, val_loss: 1.8937
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 7, time 5.0081, train_loss: 1.8680, test_loss: 1.8767, val_loss: 1.8767
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 8, time 6.6075, train_loss: 1.8515, test_loss: 1.8599, val_loss: 1.8599
#                       train_acc: 0.1229, test_acc: 0.1400, val_acc: 0.1400
# Epoch 9, time 2.1754, train_loss: 1.8315, test_loss: 1.8399, val_loss: 1.8399
#                       train_acc: 0.1886, test_acc: 0.3000, val_acc: 0.3000
# Epoch 10, time 1.8675, train_loss: 1.8130, test_loss: 1.8204, val_loss: 1.8204
#                       train_acc: 0.3543, test_acc: 0.3400, val_acc: 0.3400
# Epoch 11, time 2.5987, train_loss: 1.7923, test_loss: 1.7994, val_loss: 1.7994
#                       train_acc: 0.3229, test_acc: 0.3700, val_acc: 0.3700
# Epoch 12, time 2.7195, train_loss: 1.7692, test_loss: 1.7778, val_loss: 1.7778
#                       train_acc: 0.3771, test_acc: 0.4100, val_acc: 0.4100
# Epoch 13, time 1.5916, train_loss: 1.7474, test_loss: 1.7577, val_loss: 1.7577
#                       train_acc: 0.4029, test_acc: 0.4100, val_acc: 0.4100
# Epoch 14, time 2.5406, train_loss: 1.7290, test_loss: 1.7345, val_loss: 1.7345
#                       train_acc: 0.4114, test_acc: 0.4200, val_acc: 0.4200
# Epoch 15, time 2.4540, train_loss: 1.7044, test_loss: 1.7128, val_loss: 1.7128
#                       train_acc: 0.3914, test_acc: 0.4200, val_acc: 0.4200
# Epoch 16, time 3.1302, train_loss: 1.6808, test_loss: 1.6896, val_loss: 1.6896
#                       train_acc: 0.4343, test_acc: 0.4500, val_acc: 0.4500
# Epoch 17, time 2.4382, train_loss: 1.6605, test_loss: 1.6661, val_loss: 1.6661
#                       train_acc: 0.4114, test_acc: 0.4500, val_acc: 0.4500
# Epoch 18, time 2.3860, train_loss: 1.6280, test_loss: 1.6426, val_loss: 1.6426
#                       train_acc: 0.4714, test_acc: 0.4500, val_acc: 0.4500
# Epoch 19, time 2.1201, train_loss: 1.6037, test_loss: 1.6144, val_loss: 1.6144
#                       train_acc: 0.5029, test_acc: 0.6000, val_acc: 0.6000
# Epoch 20, time 2.1082, train_loss: 1.5723, test_loss: 1.5957, val_loss: 1.5957
#                       train_acc: 0.6029, test_acc: 0.5700, val_acc: 0.5700
# Epoch 21, time 2.7577, train_loss: 1.5503, test_loss: 1.5635, val_loss: 1.5635
#                       train_acc: 0.5857, test_acc: 0.6000, val_acc: 0.6000
# Epoch 22, time 2.7292, train_loss: 1.5188, test_loss: 1.5389, val_loss: 1.5389
#                       train_acc: 0.6143, test_acc: 0.6500, val_acc: 0.6500
# Epoch 23, time 6.9306, train_loss: 1.4940, test_loss: 1.5131, val_loss: 1.5131
#                       train_acc: 0.6571, test_acc: 0.6600, val_acc: 0.6600
# Epoch 24, time 7.7393, train_loss: 1.4676, test_loss: 1.4904, val_loss: 1.4904
#                       train_acc: 0.7057, test_acc: 0.6500, val_acc: 0.6500
# Epoch 25, time 1.8823, train_loss: 1.4431, test_loss: 1.4677, val_loss: 1.4677
#                       train_acc: 0.6886, test_acc: 0.7200, val_acc: 0.7200
# Epoch 26, time 2.5990, train_loss: 1.4175, test_loss: 1.4383, val_loss: 1.4383
#                       train_acc: 0.6971, test_acc: 0.6800, val_acc: 0.6800
# Epoch 27, time 3.1762, train_loss: 1.3855, test_loss: 1.4127, val_loss: 1.4127
#                       train_acc: 0.7114, test_acc: 0.7100, val_acc: 0.7100
# Epoch 28, time 6.6200, train_loss: 1.3567, test_loss: 1.3862, val_loss: 1.3862
#                       train_acc: 0.7000, test_acc: 0.6800, val_acc: 0.6800
# Epoch 29, time 4.9396, train_loss: 1.3369, test_loss: 1.3618, val_loss: 1.3618
#                       train_acc: 0.7143, test_acc: 0.6800, val_acc: 0.6800
# Epoch 30, time 4.9001, train_loss: 1.3046, test_loss: 1.3428, val_loss: 1.3428
#                       train_acc: 0.7086, test_acc: 0.7100, val_acc: 0.7100
# Epoch 31, time 7.6669, train_loss: 1.2850, test_loss: 1.3180, val_loss: 1.3180
#                       train_acc: 0.7114, test_acc: 0.6600, val_acc: 0.6600
# Epoch 32, time 11.1288, train_loss: 1.2504, test_loss: 1.2926, val_loss: 1.2926
#                       train_acc: 0.7000, test_acc: 0.7100, val_acc: 0.7100
# Epoch 33, time 6.1700, train_loss: 1.2244, test_loss: 1.2499, val_loss: 1.2499
#                       train_acc: 0.7057, test_acc: 0.6800, val_acc: 0.6800
# Epoch 34, time 4.6880, train_loss: 1.1879, test_loss: 1.2241, val_loss: 1.2241
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 35, time 3.8249, train_loss: 1.1631, test_loss: 1.1973, val_loss: 1.1973
#                       train_acc: 0.7000, test_acc: 0.8000, val_acc: 0.8000
# Epoch 36, time 9.1669, train_loss: 1.1339, test_loss: 1.1688, val_loss: 1.1688
#                       train_acc: 0.7343, test_acc: 0.6800, val_acc: 0.6800
# Epoch 37, time 6.3132, train_loss: 1.1118, test_loss: 1.1408, val_loss: 1.1408
#                       train_acc: 0.7086, test_acc: 0.7300, val_acc: 0.7300
# Epoch 38, time 5.5996, train_loss: 1.0760, test_loss: 1.1087, val_loss: 1.1087
#                       train_acc: 0.7143, test_acc: 0.6800, val_acc: 0.6800
# Epoch 39, time 5.1662, train_loss: 1.0464, test_loss: 1.0807, val_loss: 1.0807
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 40, time 5.1268, train_loss: 1.0171, test_loss: 1.0545, val_loss: 1.0545
#                       train_acc: 0.7543, test_acc: 0.7900, val_acc: 0.7900
# Epoch 41, time 4.0671, train_loss: 0.9913, test_loss: 1.0265, val_loss: 1.0265
#                       train_acc: 0.7829, test_acc: 0.7900, val_acc: 0.7900
# Epoch 42, time 5.4522, train_loss: 0.9630, test_loss: 1.0050, val_loss: 1.0050
#                       train_acc: 0.7571, test_acc: 0.7400, val_acc: 0.7400
# Epoch 43, time 7.2108, train_loss: 0.9449, test_loss: 0.9787, val_loss: 0.9787
#                       train_acc: 0.6971, test_acc: 0.7900, val_acc: 0.7900
# Epoch 44, time 8.5885, train_loss: 0.9213, test_loss: 0.9633, val_loss: 0.9633
#                       train_acc: 0.7771, test_acc: 0.7600, val_acc: 0.7600
# Epoch 45, time 6.8678, train_loss: 0.9050, test_loss: 0.9303, val_loss: 0.9303
#                       train_acc: 0.7800, test_acc: 0.7900, val_acc: 0.7900
# Epoch 46, time 6.5289, train_loss: 0.8718, test_loss: 0.9210, val_loss: 0.9210
#                       train_acc: 0.8000, test_acc: 0.7900, val_acc: 0.7900
# Epoch 47, time 7.9539, train_loss: 0.8591, test_loss: 0.9007, val_loss: 0.9007
#                       train_acc: 0.7800, test_acc: 0.7900, val_acc: 0.7900
# Epoch 48, time 5.2513, train_loss: 0.8420, test_loss: 0.8726, val_loss: 0.8726
#                       train_acc: 0.7743, test_acc: 0.7900, val_acc: 0.7900
# Epoch 49, time 6.0634, train_loss: 0.8229, test_loss: 0.8612, val_loss: 0.8612
#                       train_acc: 0.7829, test_acc: 0.7900, val_acc: 0.7900
